# %%
from lorem_text import lorem
import re

# %%
A=lorem.paragraph()
print(A)
# Out:
# Vel aut dolor corporis itaque sint accusamus animi facilis assumenda consectetur, earum cupiditate repellat non velit fugit consectetur architecto recusandae quo pariatur. Dolor itaque aperiam quis eius odit deleniti aliquid molestiae possimus, obcaecati a voluptatum ipsa ad magni, praesentium sequi temporibus id veritatis molestiae natus necessitatibus soluta dolore tempora, impedit tempora at est accusamus consequatur nam corporis. Vitae quaerat temporibus recusandae, maiores reprehenderit velit earum hic ut ipsum magni fuga, voluptate quis quae alias recusandae quos sit enim asperiores, nulla corrupti possimus vitae repellat atque eveniet maxime magnam.

# %%
pattern=r"quo"
matches = [match.start() for match in re.finditer(pattern, A)]
print(matches)
for i in matches:
  print(A[i:i+3])
# Out:
# [158, 571]
# quo
# quo

# %%
import emoji

# %%
print(emoji.emojize('meat :cut_of_meat:'))
# Out:
# meat 🥩

# %% [markdown]
# # 0. Computer Vision Libraries in Pytorch

# %%
import torch 
from torch import nn

import torchvision
from torchvision import datasets
from torchvision import transforms
from torchvision.transforms import ToTensor 

import matplotlib.pyplot as plt

print(torch.__version__)
print(torchvision.__version__)
# Out:
# 2.2.2
# 0.17.2

# %%
#Using Fashion MNIST Database

#IMG NET as well cool

train_data=datasets.FashionMNIST(root="data", #where it is downloaded
                                 train=1, #do we want training dataset
                                 download=1, #de we download it
                                 transform=ToTensor(), #do we transofrm data
                                 target_transform=None) #do we transform labels/targets

test_data=datasets.FashionMNIST(root="data", #where it is downloaded
                                 train=0, #do we want training dataset
                                 download=1, #de we download it
                                 transform=ToTensor(), #do we transofrm data
                                 target_transform=None) #do we transform labels/targets

# %%
len(train_data),len(test_data)
# Out:
# (60000, 10000)

# %%
# Import torch
import torch
from torch import nn
import numpy as np
from pathlib import Path

# Setup device agnostic code
if torch.cuda.is_available():
  device = "cuda"
else:
  device = "cpu"
print(device)

# Setup random seed
SEED = 42
# Out:
# cpu

# %%
image,label=train_data[0]

# %%
class_names=train_data.classes
class_names
# Out:
# ['T-shirt/top',
#  'Trouser',
#  'Pullover',
#  'Dress',
#  'Coat',
#  'Sandal',
#  'Shirt',
#  'Sneaker',
#  'Bag',
#  'Ankle boot']

# %%
train_data.targets
# Out:
# tensor([9, 0, 0,  ..., 3, 0, 5])

# %%
image.shape
# Out:
# torch.Size([1, 28, 28])

# %%
class_names[label]
# Out:
# 'Ankle boot'

# %%
plt.imshow(image.squeeze())
plt.title(label)
# Out:
# Text(0.5, 1.0, '9')

# %%
plt.imshow(image.squeeze(),cmap="gray")
plt.title(class_names[label])
# Out:
# Text(0.5, 1.0, 'Ankle boot')

# %%
torch.manual_seed(42)

fig,_=plt.subplots(figsize=(9,9))
plt.axis("off")

rows,cols=4,4
for i in range(1,rows*cols+1):
    rand_idx=torch.randint(0,len(train_data),size=[1]).item()
    img,label=train_data[rand_idx]
    fig.add_subplot(rows,cols,i)
    plt.imshow(img.squeeze(),cmap="gray")
    plt.title(class_names[label])
    plt.axis("off");

plt.show()
